# %% [markdown]
# # Modules, Packages

# %%
#Import launch codes helper
from helpers import launch_codes

# %%
launch_codes()
# Out:
# 123456789

# %% [markdown]
# checkout www.Pypi.org

# %% [markdown]
# # woring with packages

# %%
#!pip install requests

# %%
#See all packages installed
#!pip list

# %%
import requests

# %%
requests.get??

# %%
#I can haz dad joke api endpoint
joke_url = 'https://icanhazdadjoke.com'

#Iss api Endpoint
iss_url = 'https://wheretheiss.at/v1/satellites/25544'

# %%
#Setup header
my_header = {'Accept':'application/json'}

#API call
results = requests.get(joke_url,headers = my_header)

# %%
json_result = results.json()

# %%
results.json()
# Out:
# {'id': '7Uvc29hFIBd',
#  'joke': "Why are mummys scared of vacation? They're afraid to unwind.",
#  'status': 200}

# %%
type(results.json())
# Out:
# dict

# %%
json_result['joke']
# Out:
# "Why are mummys scared of vacation? They're afraid to unwind."

# %%
type(json_result['joke'])
# Out:
# str

# %%
iss_results = requests.get(iss_url, headers = my_header)

# %%
iss_results
# Out:
# <Response [404]>
