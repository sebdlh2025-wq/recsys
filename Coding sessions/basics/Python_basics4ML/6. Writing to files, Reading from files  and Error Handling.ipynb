# %% [markdown]
# # Writing to files, Reading from files  and Error Handling

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Write out mission journal
with open('mission_journal.txt', 'w') as f:
    f.write('It\'s my first day on the space mission. It is nice!!!')

# %%
open??

# %%
#Read from journal
with open('mission_journal.txt', 'r') as f:
    file = f.read()

# %%
file
# Out:
# "It's my first day on the space mission. It is nice!!!"

# %% [markdown]
# # Error Handling

# %%
    # Creare a set
new_set = {1,2,3,4,5,6}

# %%
new_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
try:
    #Run a piece of code which may cause an error
    new_set[0] = 4

    #if we have error, this code will run
except Exception as e:
    print(e)
    #print(e)
    #print('Something went wrong with your request!')
# Out:
# 'set' object does not support item assignment

# %%
new_set[0] = 4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-349934102.py in <cell line: 0>()
# ----> 1 new_set[0] = 4
#
# NameError: name 'new_set' is not defined
