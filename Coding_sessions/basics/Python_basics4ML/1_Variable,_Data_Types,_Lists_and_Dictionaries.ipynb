# %% [markdown]
# <a href="https://colab.research.google.com/github/sebdlh2025-wq/recsys/blob/main/1_Variable%2C_Data_Types%2C_Lists_and_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Variable, Data Types, Lists and DIctionaries

# %%
#Variable
space_name = 'Null pointer error'

# %%
space_name
# Out:
# 'Null pointer error'

# %%
type(space_name)
# Out:
# str

# %%
space_name = 123456

# %%
space_name
# Out:
# 123456

# %%
type(space_name)
# Out:
# int

# %%
space_name = 123456.12314

# %%
type(space_name)
# Out:
# float

# %% [markdown]
# ## Data Types

# %%
#int, str, float

# %%
test_variable = 13215

# %%
test_variable +10
# Out:
# 13225

# %%
test_variable
# Out:
# 13215

# %%
#bianry variable

# %%
bool_variabl = True
#bool_variabl = 'True'
type(bool_variabl)
#green indicates you're working with a reserved word.
# Out:
# bool

# %%
#Type casting
bool_variabl = bool(1)
type(bool_variabl)
# Out:
# bool

# %%
bool_variabl
# Out:
# True

# %%
#list variables

list_var = [1,2,3,123.123,2,2,2,2,2,3]
type(list_var)
# Out:
# list

# %%
#Assigning values
list_var[4] = 999.666

# %%
list_var
# Out:
# [1, 2, 3, 123.123, 999.666, 2, 2, 2, 2, 3]

# %%
# Tuple variables is IMMUTABLE
tuple_var = (1,2,2,3,123.123)
type(tuple_var)
# Out:
# tuple

# %%
list_var[:4         ]
# Out:
# [1, 2, 3, 123.123]

# %%
tuple_var
# Out:
# (1, 2, 2, 3, 123.123)

# %%
#tuple_var[2] = 5

# %%
#create set variables IMMUTABLE, can't change values, NO duplicates

set_var = {1,2,3,4,5,6,9}
type(set_var)
# Out:
# set

# %%
set_var
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %%
#Type casting list to a set and BACK TO A LIST to get rid of duplicates
list_var
# Out:
# [1, 2, 3, 123.123, 999.666, 2, 2, 2, 2, 3]

# %%
list_toset = set(list_var)
type(list_toset)
list_toset
# Out:
# {1, 2, 3, 123.123, 999.666}

# %%
backto_list = list(list_toset)
backto_list
# Out:
# [1, 2, 3, 999.666, 123.123]

# %%
type(set(list(backto_list)))
# Out:
# set

# %%
# Dictionary
# Key-value pairs
dict_var = {'name':"Sheldon", 'favorite': "Green", 'favorite_car': "Mini cooper", 'Favnumber': 73}
type(dict_var)
# Out:
# dict

# %% [markdown]
# Fun fact: 73 is the 21st prime number. Its mirror (37) is the 12th and its mirror (21) is the product of multiplying 7 and 3. In binary, 73 is a palindrome, 1001001 which backwards is 1001001

# %%
from IPython.display import Image
Image('Sheldon-Cooper-73.jpeg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/recsys/.venv/lib/python3.12/site-packages/IPython/core/display.py:1100, in Image._data_and_metadata(self, always_both)
#    1099 try:
# -> 1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/recsys/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# ...

# %%
print(dict_var)
# Out:
# {'name': 'Sheldon', 'favorite': 'Green', 'favorite_car': 'Mini cooper', 'Favnumber': 73}

# %%
#pass key and return the value
dict_var['name']
# Out:
# 'Sheldon'

# %% [markdown]
# ## LIST
#
# #### Create
# #### Read
# #### Update
# #### Delete

# %%
# create
names = ['Sheldon', 'Amy', 'Leonard', 'Penny']

# %%
# read
names
# Out:
# ['Sheldon', 'Amy', 'Leonard', 'Penny']

# %%
# read using index
names[2]
# Out:
# 'Leonard'

# %%
#read last vales
names[-1]
# Out:
# 'Penny'

# %%
names[-2]
# Out:
# 'Leonard'

# %%
len(names)
# Out:
# 4

# %%
#Update vales in list

names[-1] = 'Raj'

# %%
names
# Out:
# ['Sheldon', 'Amy', 'Leonard', 'Raj']

# %%
names.append('elon musk')

# %%
names
# Out:
# ['Sheldon', 'Amy', 'Leonard', 'Raj', 'elon musk']

# %%
names.insert(4,'Howard')

# %%
names
# Out:
# ['Sheldon', 'Amy', 'Leonard', 'Raj', 'Howard', 'elon musk']

# %%
names[4] = 'Stuart'

# %%
names
# Out:
# ['Sheldon', 'Amy', 'Leonard', 'Raj', 'Stuart', 'elon musk']

# %%
#Delete

del names[-2]

# %%
names
# Out:
# ['Sheldon', 'Amy', 'Leonard', 'Raj', 'elon musk']

# %% [markdown]
# ## Dictionaries

# %%
#Create

#Read

#update

#Delete

# %%
# Create

astronauts = {
            "names": "Elon musk",
            "suit size": "lage",
            "alergies": "peanust"
}

# %%
#read

astronauts['names']
# Out:
# 'Elon musk'

# %%
astronauts['suit size']
# Out:
# 'lage'

# %%
astronauts.keys()
# Out:
# dict_keys(['names', 'suit size', 'alergies'])

# %%
astronauts.values()
# Out:
# dict_values(['Elon musk', 'lage', 'peanust'])

# %%
#Update

astronauts['alergies'] = 'Mango'

# %%
astronauts
# Out:
# {'names': 'Elon musk', 'suit size': 'lage', 'alergies': 'Mango'}

# %%
astronauts['alergies']
# Out:
# 'Mango'

# %%
astronauts['space_ship'] = 'Galactic 1'

# %%
astronauts
# Out:
# {'names': 'Elon musk',
#  'suit size': 'lage',
#  'alergies': 'Mango',
#  'space_ship': 'Galactic 1'}

# %%
# Delete

# %%
del astronauts['space_ship']

# %%
astronauts
# Out:
# {'names': 'Elon musk', 'suit size': 'lage', 'alergies': 'Mango'}
